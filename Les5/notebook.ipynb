# %% [markdown]
# # mAIstros 2 - les 5: decision trees

# %% [markdown]
# ## Klaarzetten
#
# > Slide: requirements.txt

# %%
import random

import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

print("Klaar om te beginnen.")

# %% [markdown]
# ## Het allereenvoudigste voorbeeld: de data set maken
#
# > Slide: Het allereenvoudigste voorbeeld

# %%
# JOUW CODE (1)
...

# %% [markdown]
# ## Het allereenvoudigste voorbeeld: splitsen, trainen en de accuracy
#
# > Slide: Het allereenvoudigste voorbeeld
#
# De twee cellen hierna werken met `dt`. Zet jouw getrainde decision tree dus in `dt`.

# %%
# JOUW CODE (2)
...

# %% [markdown]
# ## Het allereenvoudigste voorbeeld: de regels als tekst
#
# > Slide: Het allereenvoudigste voorbeeld

# %%
regels_als_tekst = tree.export_text(dt, feature_names=["Getal"])
print(regels_als_tekst)

# %% [markdown]
# ## Het allereenvoudigste voorbeeld: de regels visualiseren
#
# > Slide: Het allereenvoudigste voorbeeld

# %%
fig = plt.figure(figsize=(25, 20))
_ = tree.plot_tree(dt, feature_names=["Getal"],
                   class_names=["Soort 1", "Soort 2", "Soort 3"],
                   filled=True, impurity=False)
fig.savefig("decision_tree.png")

# %% [markdown]
# ## Een tweede voorbeeld - Stap 1: de wezens genereren
#
# > Slide: Een tweede voorbeeld - Stap 1

# %%
# JOUW CODE (3)
...

# %% [markdown]
# ## Een tweede voorbeeld - Stap 2: trainen, testen en de boom visualiseren
#
# > Slide: Een tweede voorbeeld - Stap 2

# %%
# JOUW CODE (4)
...

# %% [markdown]
# ## Alhaj Airlines - Stap 1: het bestand inlezen
#
# > Slide: Oefening: Alhaj Airlines - Stap 1

# %%
BESTAND = "airlines_tevredenheid.csv"

# JOUW CODE (5)
...

# %% [markdown]
# ## Alhaj Airlines - Stap 2: de correcte lijnen tellen
#
# > Slide: Oefening: Alhaj Airlines - Stap 2

# %%
# JOUW CODE (6)
...

# %% [markdown]
# ## Alhaj Airlines - Stap 3: xwaarden en ywaarden opvullen
#
# > Slide: Oefening: Alhaj Airlines - Stap 3

# %%
# JOUW CODE (7)
...

# %% [markdown]
# ## Alhaj Airlines - Stap 4: trainen en de accuracy
#
# > Slide: Oefening: Alhaj Airlines - Stap 4

# %%
# JOUW CODE (8)
...

# %% [markdown]
# ## Alhaj Airlines - Stap 5: de boom visualiseren
#
# > Slide: Oefening: Alhaj Airlines - Stap 5

# %%
# JOUW CODE (9)
...

# %% [markdown]
# ## Een kleinere boom
#
# > Slide: Een leesbare boom of een accurate boom?

# %%
# JOUW CODE (10)
...
