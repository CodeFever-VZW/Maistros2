# %% [markdown]
# # mAIstros 2 - les 1: lineaire regressie
#
# Dit is je startcode. De vaste code staat er al in.
# Jij vult aan op de plaatsen die aangeduid staan.
# Werk van boven naar beneden en voer elke cel uit voor je verdergaat.

# %% [markdown]
# ## Controleren doe je zelf
#
# Je cel draait zonder foutmelding. Maar klopt het resultaat? Dat is een tweede vraag.
#
# Daarom staat na elke stap een blok **Controleer je werk**. Daarin staat wat waar
# moet zijn als je cel gedraaid heeft, in woorden en in getallen. Daaronder staat een
# lege cel. Jij schrijft daarin de code die laat zien dat het klopt. Meestal is dat
# één print.
#
# Er is geen knop die "juist" of "fout" zegt. Jij vergelijkt wat je ziet met wat er
# staat. Komt het niet overeen, dan weet je meteen welke stap je opnieuw bekijkt.
#
# Zelf controleren is geen extra werk naast het programmeren. Het hoort erbij.
# Onderweg leer je een paar manieren om te kijken. Elke manier krijgt een naam, zodat
# je ze later opnieuw kunt gebruiken.

# %% [markdown]
# ### Techniek: print() en repr()
#
# `print()` toont de tekst zoals ze eruitziet. `repr()` toont ook wat je niet ziet:
# het regeleinde, spaties op het einde, en of iets tekst is of een getal.
#
# Voer de cel hieronder uit en vergelijk de twee regels.

# %%
print('12.4\n')
print(repr('12.4\n'))

# %% [markdown]
# De eerste regel laat een lege rij achter en je ziet niet waarom. De tweede toont
# `'12.4\n'`. Nu zie je het regeleinde staan, en de aanhalingstekens vertellen je dat
# dit tekst is en geen getal.
#
# Dat onzichtbare teken is de klassieke eerste fout bij het inlezen van een bestand.
# Kijk er met `repr()` naar zodra iets niet klopt.

# %% [markdown]
# ## Opwarmer
#
# > Slides: Opwarmer 1 tot en met Opwarmer 4
#
# Vier korte bewerkingen op één rij tekst. Je hebt ze zo dadelijk alle vier nodig.
#
# Waar `JOUW CODE` staat, schrijf jij code. De drie puntjes `...` vervang je. Onder
# elke opdracht staat wat er moet kloppen. Hoe je daar geraakt, kies je zelf.

# %%
rij = "[12.4, 9.8, 15.1]\n"

# JOUW CODE (opwarmer 1)
# zonder_regeleinde bevat dezelfde tekst als rij, maar zonder het regeleinde.
zonder_regeleinde = ...

# JOUW CODE (opwarmer 2)
# zonder_haken bevat dezelfde tekst, maar zonder de rechte haken.
zonder_haken = ...

# JOUW CODE (opwarmer 3)
# waarden is een lijst met de drie waarden apart, elk nog als tekst en zonder
# spaties eromheen.
waarden = ...

# JOUW CODE (opwarmer 4)
# graden bevat dezelfde drie waarden, maar als kommagetal in plaats van tekst.
graden = ...

# %% [markdown]
# ### Techniek: len()
#
# `len()` beantwoordt één vraag: hoeveel hou ik over? Het werkt op een lijst en op
# tekst.

# %% [markdown]
# ### Techniek: twee lijsten naast elkaar
#
# Horen twee lijsten bij elkaar, dan moet `len(a) == len(b)` waar zijn. Als ze uit
# elkaar lopen, hoort waarde 5 van de ene niet meer bij waarde 5 van de andere.

# %% [markdown]
# ### Techniek: type()
#
# `type()` zegt of iets tekst is of een getal. `"12.4"` en `12.4` zien er in een
# print precies hetzelfde uit, maar met de eerste kun je niet rekenen.

# %% [markdown]
# ### Controleer je werk - opwarmer
#
# Als deze cel gedraaid heeft:
#
# - `zonder_regeleinde` is `'[12.4, 9.8, 15.1]'`, dus zonder het regeleinde op het einde;
# - `zonder_haken` is `'12.4, 9.8, 15.1'`, of hetzelfde zonder de spaties;
# - `waarden` bevat 3 stukjes tekst: `'12.4'`, `'9.8'` en `'15.1'`;
# - `graden` bevat 3 kommagetallen: `12.4`, `9.8` en `15.1`;
# - `waarden` en `graden` zijn dus even lang.
#
# Laat zelf zien dat dat klopt. Gebruik `repr()` voor de twee stukken tekst, want een
# gewone print toont het regeleinde niet. Gebruik `len()` voor de twee lijsten, en
# `type()` om te zien of er in `graden` echt getallen zitten.

# %%
# JOUW CONTROLE (opwarmer)
# Schrijf hier de code die laat zien dat het bovenstaande klopt.

# %% [markdown]
# ## Klaarzetten
#
# > Slide: requirements.txt
#
# Installeer de pakketten uit `requirements.txt`. De slide toont hoe. Voer daarna
# de cel hieronder uit. Je ziet `Klaar om te beginnen.` staan.

# %%
# Het pakket met de modellen. Je gebruikt het in oefening 1 en in oefening 2.
from sklearn import linear_model

print("Klaar om te beginnen.")

# %% [markdown]
# ## Oefening 1 - ons eigen model
#
# > Slide: Oef 1: ons eigen lineaire regressie model
#
# Je voorspelt de y-waarde voor x = 20 en voor x = 24. Dat gaat in drie stappen.
# Eerst lees je de data in. Daarna kuis je ze op. Ten slotte schrijf je een model.

# %% [markdown]
# ### Stap 1 - de data in je notebook krijgen
#
# > Slide: Oef 1 - stap 1: de data in onze notebook importeren
#
# Je hebt hier `linreg_oef1.txt` nodig. Download het via de knop op die slide en
# zet het in dezelfde map als dit bestand. Hier programmeer je nog niets.
#
# De cel hieronder opent het bestand en bekijkt de eerste rij. De rij is lang, dus
# we tonen alleen het begin en het einde. Lees de code, je hebt ze in stap 2 nodig.
#
# Vindt Python het bestand niet? Op deze slide staat een hint van Codi.

# %%
# De naam van het databestand. Heet jouw download anders? Pas dan deze naam aan.
BESTAND_OEF1 = "linreg_oef1.txt"

f = open(BESTAND_OEF1, "r", encoding="utf-8")
eerste_rij = f.readline()
f.close()

print(eerste_rij[:60])
print(repr(eerste_rij[:60]))
print(repr(eerste_rij[-30:]))

# %% [markdown]
# ### Controleer je werk - stap 1
#
# Als deze cel gedraaid heeft:
#
# - je krijgt geen `FileNotFoundError`, dus Python vindt het bestand;
# - de eerste regel begint met `[25.997575939480946, 25.830453720305528,`;
# - de tweede regel toont hetzelfde tussen aanhalingstekens, dus dit is tekst;
# - de derde regel eindigt op `9.36692154274855]\n`, en `\n` is het regeleinde.
#
# Het bestand heeft twee rijen. Laat zelf zien dat de tweede rij er ook is: open het
# bestand, lees twee rijen na elkaar en druk het einde van de tweede af met `repr()`.
# Die tweede rij eindigt niet op een regeleinde, want er komt niets meer na.

# %%
# JOUW CONTROLE (stap 1)
# Schrijf hier de code die laat zien dat het bovenstaande klopt.

# %% [markdown]
# ### Stap 2 - de data opkuisen
#
# > Slide: Oef 1 - stap 2: de data opkuisen
#
# Het bestand heeft twee rijen. Op de eerste rij staan de x-waarden. Op de
# tweede rij staan de y-waarden. Het ziet eruit als een lijst, maar het is tekst.
#
# Wat er moet kloppen als de cel gedraaid heeft: je hebt alle getallen van de eerste
# rij in één lijst en alle getallen van de tweede rij in een tweede lijst. Het zijn
# kommagetallen, geen tekst. De slide noemt die twee lijsten `xwaarden` en
# `ywaarden`. Hou die namen aan, dan lezen de slide en jouw code hetzelfde. Hoe je
# de lijsten vult, kies je zelf.
#
# Vast? Op deze slide staan hints van Codi.

# %%
# Het bestand openen doen wij voor jou.
f = open(BESTAND_OEF1, "r", encoding="utf-8")

# JOUW CODE (2)
# Zet de getallen van de eerste rij in een lijst en die van de tweede rij in een
# tweede lijst.
...

f.close()

# %% [markdown]
# ### Techniek: de eerste drie
#
# `lijst[:3]` toont de eerste drie waarden in plaats van alle honderd. Genoeg om te
# zien of je op de goede weg zit, en je scherm blijft leesbaar.

# %% [markdown]
# ### Controleer je werk - stap 2
#
# Als deze cel gedraaid heeft:
#
# - elke lijst bevat 42 waarden, dus even veel;
# - de eerste drie x-waarden zijn ongeveer 26,0 en 25,8 en 5,2;
# - de eerste drie y-waarden zijn ongeveer 83,0 en 81,8 en 20,7;
# - het zijn kommagetallen, dus `type()` zegt `float` en niet `str`.
#
# Laat zelf zien dat dat klopt. `len()` geeft je de twee aantallen, `lijst[:3]` de
# eerste drie waarden, en `type()` van één waarde zegt of het al een getal is.
#
# Staat de eerste rij van het bestand in de lijst met y-waarden? Dan staan x en y
# omgewisseld. Je merkt dat aan de eerste drie waarden.

# %%
# JOUW CONTROLE (stap 2)
# Schrijf hier de code die laat zien dat het bovenstaande klopt.

# %% [markdown]
# ### Stap 3 - ons model schrijven
#
# > Slide: Oef 1 - stap 3: ons model schrijven
#
# Wat er moet kloppen als de cel gedraaid heeft: je hebt de twee y-waarden die een
# op je twee lijsten getraind model geeft voor x = 20 en voor x = 24.
#
# De slides na deze behandelen elk onderdeel apart: een ongetraind model
# klaarzetten, de x-waarden in de juiste vorm zetten, trainen, en voorspellen. Op
# vier van die slides staat een hint van Codi.
#
# Wil je eerst zien wat trainen doet? Sleep zelf een lijn door de punten op
# https://maistros2-demos.netlify.app/les1/teken-de-lijn

# %%
# JOUW CODE (3)
# Train een lineair regressiemodel op je twee lijsten. Vraag het daarna de y-waarde
# voor x = 20 en voor x = 24.
...

# %% [markdown]
# ### Controleer je werk - stap 3
#
# Als deze cel gedraaid heeft:
#
# - je hebt twee voorspelde y-waarden;
# - de eerste hoort bij x = 20 en is ongeveer 65,63;
# - de tweede hoort bij x = 24 en is ongeveer 77,26;
# - vraag je de twee waarden in één keer op, dan zet Python er `array(...)` rond.
#
# De slide `Oef 1 - stap 3: kloppen de voorspelde waarden?` toont dezelfde twee
# getallen. Druk je resultaat af en vergelijk.
#
# Krijg je de twee getallen in de omgekeerde volgorde? Kijk dan na in welke volgorde
# je 20 en 24 aan je model gaf.

# %%
# JOUW CONTROLE (stap 3)
# Schrijf hier de code die laat zien dat het bovenstaande klopt.

# %% [markdown]
# ## Train set, test set en score
#
# > Slides: Data splitsen in Train set & Test set, en De score meten op de test set
#
# Hier programmeer je niets. Deze twee slides tonen waarom je je data in een train
# set en een test set splitst. Ze tonen ook wat de score van een model betekent.
# Allebei gebruik je meteen in oefening 2.
#
# Wil je zelf voelen wat een score doet? Kantel de lijn op
# https://maistros2-demos.netlify.app/les1/hoe-goed-past-de-lijn

# %% [markdown]
# ## Oefening 2 - een model trainen en de score berekenen
#
# > Slide: Oefening 2: train een model & bereken de score
#
# Je hebt hier twee bestanden nodig: `oef2_train_set.csv` en `oef2_test_set.csv`.
# Download ze via de knoppen op die slide en zet ze in dezelfde map als dit
# bestand. Laat de namen staan zoals ze zijn.
#
# Bekijk daarna de data. Kijk goed hoe een rij is opgebouwd. Dat heb je nodig om
# je lijsten met x-waarden en y-waarden te maken.

# %%
# De namen van de twee databestanden. Heten jouw downloads anders? Pas dan deze
# twee namen aan.
BESTAND_TRAIN = "oef2_train_set.csv"
BESTAND_TEST = "oef2_test_set.csv"

# %% [markdown]
# ### Controleer je werk - de twee bestanden
#
# Als de twee bestanden op de juiste plaats staan:
#
# - je krijgt geen `FileNotFoundError` als je ze opent;
# - de eerste rij van de train set is `'33,41\n'`, dus met een regeleinde erachter;
# - elke rij bevat één meting: een x-waarde, een komma, een y-waarde;
# - er is geen rij met kolomnamen en er staan geen haken rond.
#
# Laat zelf zien dat dat klopt. Open elk bestand, lees de eerste rij en druk ze af
# met `repr()`. Zo zie je meteen of er nog een regeleinde aan hangt.

# %%
# JOUW CONTROLE (bestanden oefening 2)
# Schrijf hier de code die laat zien dat het bovenstaande klopt.

# %% [markdown]
# ### Stap 4 - het programma
#
# > Slide: Oefening 2: train een model & bereken de score, stap 4
#
# Wat er moet kloppen als de cel gedraaid heeft:
#
# - je hebt de x- en y-waarden van de train set;
# - je hebt die van de test set;
# - je weet hoe goed een op de train set getraind model bij de test set past.
#
# Hoe je het aanpakt en hoe je je lijsten noemt, kies je zelf.
#
# Vast? Op deze slide staan hints van Codi.

# %%
# De twee bestanden openen doen wij voor jou.
trainf = open(BESTAND_TRAIN, "r", encoding="utf-8")
testf = open(BESTAND_TEST, "r", encoding="utf-8")

# JOUW CODE (4a)
# Maak voor de train set een lijst met x-waarden en een lijst met y-waarden. Doe
# daarna hetzelfde voor de test set.
...

# JOUW CODE (4b)
# Train een lineair regressiemodel op de train set. Bereken daarna hoe goed dat
# model bij de test set past.
...

trainf.close()
testf.close()

# %% [markdown]
# ### Controleer je werk - stap 4
#
# Als deze cel gedraaid heeft:
#
# - de train set telt 26 rijen, dus 26 x-waarden en 26 y-waarden;
# - de test set telt 15 rijen, dus 15 x-waarden en 15 y-waarden;
# - de x-lijst en de y-lijst van dezelfde set zijn dus even lang;
# - de score is 1.0.
#
# Laat zelf zien dat dat klopt. Vier keer `len()` en één print van de score volstaat.
#
# Krijg je een lagere score? Kijk dan na of x en y niet omgewisseld staan, en of je
# traint op de train set.
#
# Eén ding kan de score je hier niet vertellen. Deze oefendata ligt exact op een
# rechte lijn. Scoor je per ongeluk op de train set, dan krijg je ook 1.0 en zie je
# dus niets. Lees daarom zelf na of in je `score()` de lijsten van de test set staan.
#
# Die 1.0 is hier normaal, net omdat de punten exact op een lijn liggen. Echte data
# ligt nooit zo netjes. In les 2 kom je scores tegen die veel lager liggen, en die
# zijn daarom niet fout.

# %%
# JOUW CONTROLE (stap 4)
# Schrijf hier de code die laat zien dat het bovenstaande klopt.

# %% [markdown]
# ## Zelf doen (extra, thuis)
#
# > Slide: Zelf doen!
#
# Verzamel je eigen data en voorspel er iets mee. Twee lijsten met getallen die bij
# elkaar horen is genoeg. Alles wat je nodig hebt staat hierboven. Inlezen, elke x
# in zijn eigen lijstje, trainen, en de score berekenen.
#
# Controleer ook hier je werk. Tel je rijen met `len()`, bekijk de eerste drie met
# `lijst[:3]`, en kijk met `type()` of je al met getallen werkt.
#
# Weet je niet hoe je begint? Op deze slide staat een hint van Codi.
#
# Wil je je eigen data ook visualiseren? Dan heb je matplotlib nodig. Dat pakket
# staat niet in de `requirements.txt` van les 1. In die van les 2 staat het wel.
# Installeer die eerst. Zet daarna de code in de cel hieronder aan en vul je eigen
# twee lijsten in.

# %%
# Zet deze code aan zodra je matplotlib hebt.
# import matplotlib.pyplot as plt
# plt.scatter(mijn_x_lijst, mijn_y_lijst, c=[(1.0, 0.0, 0.0)])
# plt.show()
