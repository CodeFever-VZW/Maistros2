# %% [markdown]
# # mAIstros 2 - les 1: lineaire regressie

# %% [markdown]
# ## Opwarmer
#
# > Slides: eerst Tussendoor: hoe weet je of je code juist is?
# > Daarna Opwarmer 1 tot en met Opwarmer 4.

# %%
rij = "[12.4, 9.8, 15.1]\n"

# JOUW CODE (opwarmer 1)
# zonder_regeleinde: dezelfde tekst als rij, zonder het regeleinde.
zonder_regeleinde = ...

# JOUW CODE (opwarmer 2)
# zonder_haken: dezelfde tekst, zonder de rechte haken.
zonder_haken = ...

# JOUW CODE (opwarmer 3)
# waarden: de drie waarden apart, elk nog als tekst.
waarden = ...

# JOUW CODE (opwarmer 4)
# graden: dezelfde drie waarden, als kommagetal.
graden = ...

# %% [markdown]
# ## Klaarzetten
#
# > Slide: requirements.txt

# %%
from sklearn import linear_model

print("Klaar om te beginnen.")

# %% [markdown]
# ## Oefening 1 - stap 2: de data opkuisen
#
# > Slides: eerst Oef 1: ons eigen lineaire regressie model en Oef 1 - stap 1.
# > Daarna Oef 1 - stap 2: de data opkuisen.

# %%
BESTAND_OEF1 = "linreg_oef1.txt"

# JOUW CODE (2)
...

# %% [markdown]
# ## Oefening 1 - stap 3: ons model schrijven
#
# > Slide: Oef 1 - stap 3: ons model schrijven

# %%
# JOUW CODE (3)
...

# %% [markdown]
# ## Oefening 2 - stap 4: het programma
#
# > Slides: eerst Data splitsen in Train set & Test set en De score meten op de test set.
# > Daarna Oefening 2: train een model & bereken de score, stap 1 tot 3.
# > Stap 4 staat op de slide erna.

# %%
BESTAND_TRAIN = "oef2_train_set.csv"
BESTAND_TEST = "oef2_test_set.csv"

# JOUW CODE (4)
...

# %% [markdown]
# ## Zelf doen (extra, thuis)
#
# > Slide: Zelf doen!

# %%
# JOUW CODE (zelf doen)
...
