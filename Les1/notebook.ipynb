# %% [markdown]
# # mAIstros 2 - les 1: lineaire regressie
#
# Dit is je startbestand. De vaste code staat er al in. Jij schrijft de stukken
# die het lesdoel zijn.
#
# Zo werk je:
#
# 1. Zet dit bestand en de databestanden in dezelfde map.
# 2. Werk van boven naar beneden. Voer elke cel uit voor je verder gaat.
# 3. Waar `JOUW CODE` staat, schrijf jij code. De drie puntjes `...` vervang je.
# 4. Na een stap volgt vaak een zelfcontrole. Die kijkt of je code gedraaid heeft.
#    Ze geeft je nooit het antwoord op een vraag van een slide.
# 5. Een cel die je nog niet hebt ingevuld, geeft een foutmelding. Dat is normaal.
#
# Elke stap noemt de slide waar de opdracht staat. Die regel begint met `Slide:`.
# Ben je de draad kwijt? Kijk naar het scherm en zoek die slide.
#
# Op veel slides staan hints van Codi. Kom je er niet uit? Open die hints. Ze
# zetten je op weg. Ze geven je de code niet.
#
# Je hebt drie databestanden nodig. Voor oefening 1 is dat `linreg_oef1.txt`.
# Voor oefening 2 zijn dat `oef2_train_set.csv` en `oef2_test_set.csv`. Je
# downloadt ze via de knoppen op de slides.

# %% [markdown]
# ## Voor je begint
#
# > Slide: requirements.txt
#
# Installeer eerst de pakketten uit `requirements.txt`. De slide toont hoe. Voer
# daarna de cel hieronder uit.
#
# Zelfcontrole: je ziet `Klaar om te beginnen.` staan.

# %%
# De namen van de databestanden. Heet jouw download anders? Pas dan deze drie
# regels aan en verder niets.
BESTAND_OEF1 = "linreg_oef1.txt"
BESTAND_TRAIN = "oef2_train_set.csv"
BESTAND_TEST = "oef2_test_set.csv"

# Het pakket met de modellen. Je gebruikt het in oefening 1 en in oefening 2.
from sklearn import linear_model

print("Klaar om te beginnen.")

# %% [markdown]
# ## Opwarmer
#
# > Slides: Opwarmer 1 tot en met Opwarmer 4
#
# Op de slides beantwoord je vier korte vragen. Hier typ je diezelfde vier
# bewerkingen zelf. Je gebruikt ze alle vier in stap 2.
#
# Werkt er iets niet? Los het hier op. Stap 2 gaat daarna veel vlotter.

# %%
regel = "[12.4, 9.8, 15.1]\n"

# JOUW CODE (opwarmer 1)
# Haal het regeleinde van regel weg.
zonder_regeleinde = ...

# JOUW CODE (opwarmer 2)
# Haal de rechte haken [ en ] uit zonder_regeleinde weg.
zonder_haken = ...

# JOUW CODE (opwarmer 3)
# Haal de spaties uit zonder_haken weg. Splits daarna op de komma.
stukjes = ...

# JOUW CODE (opwarmer 4)
# Zet elk stukje uit stukjes om naar een kommagetal. Voeg het toe aan graden.
graden = []
...

# %%
# Zelfcontrole opwarmer
# Elke opwarmer-slide toont wat je bij die stap moet overhouden. Vergelijk zelf.
print(zonder_regeleinde)
print(zonder_haken)
print(stukjes)
print(graden)
print(len(graden))   # dit moet 3 zijn: er staan drie getallen in regel

# %% [markdown]
# ## Oefening 1 - ons eigen model
#
# > Slide: Oef 1: ons eigen lineaire regressie model
#
# Je voorspelt de y-waarde voor x = 20 en voor x = 24. Dat doe je in drie stappen.
# Eerst lees je de data in. Daarna kuis je ze op. Ten slotte schrijf je een model.

# %% [markdown]
# ### Stap 1 - de data in je notebook krijgen
#
# > Slide: Oef 1 - stap 1: de data in onze notebook importeren
#
# Download `linreg_oef1.txt` via de knop op de slide. Zet het bestand in dezelfde
# map als dit bestand. Hier programmeer je nog niets.
#
# Vindt Python het bestand niet? Open de hints van Codi op deze slide.
#
# Zelfcontrole: je ziet het begin van de eerste lijn. Krijg je een foutmelding?
# Dan staat het bestand niet in de juiste map.

# %%
# Zelfcontrole stap 1
f = open(BESTAND_OEF1, "r", encoding="utf-8")
print(f.readline()[:40])
f.close()

# %% [markdown]
# ### Stap 2 - de data opkuisen
#
# > Slide: Oef 1 - stap 2: de data opkuisen
#
# Het bestand heeft twee lijnen. Op de eerste lijn staan de x-waarden. Op de
# tweede lijn staan de y-waarden. Het ziet eruit als een lijst, maar het is tekst.
# Jij maakt er twee lijsten van kommagetallen van.
#
# Vast? Open de hints van Codi op deze slide.
#
# Zelfcontrole: de twee lijsten zijn even lang. In de lijsten staan kommagetallen
# en geen tekst.

# %%
# Het bestand openen doen wij voor jou.
f = open(BESTAND_OEF1, "r", encoding="utf-8")

# JOUW CODE (2a)
# Lees de eerste lijn in x en de tweede lijn in y. Haal meteen het regeleinde weg.
x = ...
y = ...

# JOUW CODE (2b)
# Haal de rechte haken uit x en uit y weg. Haal ook alle spaties weg.
...

# JOUW CODE (2c)
# Splits x en y op de komma. Je krijgt twee lijsten met stukjes tekst.
xstrings = ...
ystrings = ...

# JOUW CODE (2d)
# Vul xwaarden en ywaarden. Zet elk stukje tekst eerst om naar een kommagetal.
xwaarden = []
ywaarden = []
...

# %%
# Zelfcontrole stap 2
print(len(xwaarden), len(ywaarden))   # deze twee getallen moeten gelijk zijn
print(xwaarden[:3])
print(ywaarden[:3])

# %% [markdown]
# ### Stap 3 - ons model schrijven
#
# > Slide: Oef 1 - stap 3: ons model schrijven
#
# Je doet vier dingen. Je zet een leeg model klaar. Je stopt elke x-waarde in een
# eigen klein lijstje. Je traint het model. Je vraagt een voorspelling voor x = 20
# en voor x = 24.
#
# De vier slides na deze tonen elk stuk apart. Kom je vast? Lees ze opnieuw.
#
# Wil je eerst zien wat trainen doet? Sleep zelf een lijn door de punten op
# https://maistros2-demos.netlify.app/les1/teken-de-lijn
#
# Zelfcontrole: je ziet twee getallen. Vergelijk ze met de slide `Oef 1 - stap 3:
# kloppen de voorspelde waarden?`

# %%
# JOUW CODE (3a)
# Zet een nog ongetraind lineair regressiemodel in regr.
regr = ...

# JOUW CODE (3b)
# Vul xwaarden_lr. Elk getal uit xwaarden komt in zijn eigen klein lijstje.
xwaarden_lr = []
...

# JOUW CODE (3c)
# Train het model op xwaarden_lr en ywaarden.
...

# JOUW CODE (3d)
# Vraag het getrainde model een voorspelling. Doe dat voor x = 20 en voor x = 24.
voorspelling = ...

# %%
# Zelfcontrole stap 3
print(voorspelling)   # twee getallen; vergelijk ze met de slide

# %% [markdown]
# ## Train set, test set en score
#
# > Slides: Data splitsen in Train set & Test set, en De score meten op de test set
#
# Hier programmeer je niets. Deze twee slides tonen waarom je je data in twee
# stukken splitst. Ze tonen ook wat de score van een model betekent. Allebei
# gebruik je meteen in oefening 2.
#
# Wil je zelf voelen wat een score doet? Kantel de lijn op
# https://maistros2-demos.netlify.app/les1/hoe-goed-past-de-lijn

# %% [markdown]
# ## Oefening 2 - een model trainen en de score berekenen
#
# > Slide: Oefening 2: train een model & bereken de score
#
# Stap 1: download de twee bestanden via de knoppen op de slide.
#
# Stap 2: zet ze in dezelfde map als dit bestand. Laat de namen staan zoals ze
# zijn. De code hieronder opent ze onder die naam.
#
# Stap 3: bekijk de data. Kijk goed hoe een lijn is opgebouwd. Dat heb je nodig om
# je lijsten met x-waarden en y-waarden te maken.
#
# Zelfcontrole: je ziet de eerste lijn van de train set.

# %%
# Zelfcontrole stap 1 tot 3
g = open(BESTAND_TRAIN, "r", encoding="utf-8")
print(g.readline().strip())
g.close()

# %% [markdown]
# ### Stap 4 - het programma
#
# > Slide: Oefening 2: train een model & bereken de score, stap 4
#
# Je programma doet vier dingen. Het leest allebei de bestanden in. Het maakt per
# bestand een lijst met x-waarden en een lijst met y-waarden. Het traint een model
# op de train set. Het berekent daarna de score op de test set.
#
# Vast? Open de hints van Codi op deze slide.
#
# Zelfcontrole: je ziet één getal achter `Score =`.

# %%
# De twee bestanden openen doen wij voor jou.
trainf = open(BESTAND_TRAIN, "r", encoding="utf-8")
testf = open(BESTAND_TEST, "r", encoding="utf-8")

trainxwaarden = []
trainywaarden = []
# JOUW CODE (4a)
# Overloop trainf lijn per lijn. Vul trainxwaarden en trainywaarden. Denk aan het
# regeleinde. Elke x moet in zijn eigen klein lijstje, net als in oefening 1.
...

testxwaarden = []
testywaarden = []
# JOUW CODE (4b)
# Doe precies hetzelfde voor testf, met testxwaarden en testywaarden.
...

# JOUW CODE (4c)
# Zet een nieuw lineair regressiemodel in regr.
regr = ...

# JOUW CODE (4d)
# Train regr op de train set.
...

# JOUW CODE (4e)
# Bereken hoe goed het getrainde model bij de test set past. Zet dat getal in
# score.
score = ...

# %%
# Zelfcontrole stap 4
print("Score =", score)

# %% [markdown]
# ## Zelf doen (extra, thuis)
#
# > Slide: Zelf doen!
#
# Verzamel je eigen data en voorspel er iets mee. Twee lijsten met getallen die bij
# elkaar horen is genoeg. Alles wat je nodig hebt staat hierboven. Inlezen, elke x
# in zijn eigen lijstje, trainen, en de score berekenen.
#
# Weet je niet hoe je begint? Open de hints van Codi op deze slide.
#
# Wil je je eigen data ook zien? Dan heb je matplotlib nodig. Dat pakket staat niet
# in de `requirements.txt` van les 1. In die van les 2 staat het wel. Installeer
# die eerst. Zet daarna de regels in de cel hieronder aan.

# %%
# Zet deze drie regels aan zodra je matplotlib hebt.
# import matplotlib.pyplot as plt
# plt.scatter(xwaarden, ywaarden, c=[(1.0, 0.0, 0.0)])
# plt.show()
