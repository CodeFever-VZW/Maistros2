# %% [markdown]
# # mAIstros 2 - les 3: classificatie met logistische regressie

# %% [markdown]
# ## Klaarzetten
#
# > Slide: requirements.txt

# %%
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn import model_selection

print("Klaar om te beginnen.")

# %% [markdown]
# ## Oefening 1 - stap 1: de lijnen inlezen
#
# > Slide: Oefening 1 - Stap 1

# %%
BESTAND_OEF1 = "kleuren-cf.txt"

# JOUW CODE (1)
...

# %% [markdown]
# ## Oefening 1 - stap 2: de eerste tien lijnen in twee lijsten
#
# > Slide: Oefening 1 - Stap 2

# %%
# JOUW CODE (2)
...

# %% [markdown]
# ## Oefening 1 - stap 2: de functie is_float()
#
# > Slide: Oefening 1 - Stap 2
#
# De tests onder je code gebruiken `is_float()`.

# %%
# JOUW CODE (3)
...

print(is_float("-12.0"))
print(is_float("12.0"))
print(is_float(".0"))
print(is_float("-12.3456"))
print(is_float("-0.0"))
print(is_float("-1a2.0"))
print(is_float("-1.2.0"))
print(is_float("kip"))

# %% [markdown]
# ## Oefening 1 - stap 2: alle lijnen, met is_float()
#
# > Slide: Oefening 1 - Stap 2

# %%
# JOUW CODE (4)
...

# %% [markdown]
# ## Oefening 1 - stap 2: tellen hoe vaak elk personage voorkomt
#
# > Slide: Oefening 1 - Stap 2

# %%
# JOUW CODE (5)
...

# %% [markdown]
# ## Oefening 1 - stap 2: alleen geldige personages
#
# > Slide: Oefening 1 - Stap 2
#
# Latere cellen werken verder met de `rgbs` en `personages` uit deze cel.

# %%
# JOUW CODE (6)
...

# %% [markdown]
# ## Oefening 1 - stap 3: train set en test set
#
# > Slide: Oefening 1 - Stap 3

# %%
# JOUW CODE (7)
...

# %% [markdown]
# ## Oefening 1 - stap 4: het model trainen
#
# > Slide: Oefening 1 - Stap 4

# %%
# JOUW CODE (8)
...

# %% [markdown]
# ## Oefening 1 - stap 5: voorspellingen maken
#
# > Slide: Oefening 1 - Stap 5

# %%
# JOUW CODE (9)
...

# %% [markdown]
# ## Oefening 1 - stap 6: de accuracy berekenen
#
# > Slide: Oefening 1 - Stap 6

# %%
# JOUW CODE (10)
...

# %% [markdown]
# ## Oefening 1 - stap 7: de voorspellingen visualiseren
#
# > Slide: Oefening 1 - Stap 7

# %%
# JOUW CODE (11)
...

# %% [markdown]
# ## Oefening 2 - stap 1: de lijnen inlezen
#
# > Slide: Oefening 2 - Stap 1

# %%
BESTAND_OEF2 = "sonar-data.txt"

# JOUW CODE (12)
...

# %% [markdown]
# ## Oefening 2 - stap 2: de waarden en de antwoorden apart
#
# > Slide: Oefening 2 - Stap 2

# %%
# JOUW CODE (13)
...

# %% [markdown]
# ## Oefening 2 - stap 3: train set en test set
#
# > Slide: Oefening 2 - Stap 3

# %%
# JOUW CODE (14)
...

# %% [markdown]
# ## Oefening 2 - stap 4: trainen en voorspellen
#
# > Slide: Oefening 2 - Stap 4

# %%
# JOUW CODE (15)
...

# %% [markdown]
# ## Oefening 2 - stap 5: de accuracy berekenen
#
# > Slide: Oefening 2 - Stap 5

# %%
# JOUW CODE (16)
...

# %% [markdown]
# ## Oefening 2 - stap 6: de accuracy per klasse
#
# > Slide: Oefening 2 - Stap 6

# %%
# JOUW CODE (17)
...
